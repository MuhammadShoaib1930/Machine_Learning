# %% [markdown]
# Data analytics

# %%
import numpy as np 
import pandas as pd

name1 = "datasets/2026 QS World University Rankings.csv"
name2 = "datasets/Mobile Phone Pricing.csv"
ds1 = pd.read_csv(name1)
ds2 = pd.read_csv(name2)
ds1.head(3)
# Out:
#   2026 Rank Previous Rank                             Institution Name  \
# 0         1             1  Massachusetts Institute of Technology (MIT)
# 1         2             2                      Imperial College London
# 2         3             6                          Stanford University
#
#           Country/Territory    Region Size Focus Research  \
# 0  United States of America  Americas    M    CO       VH
# 1            United Kingdom    Europe    L    FO       VH
# 2  United States of America  Americas    L    FC       VH
#
#                    Status  AR SCORE  ... ISR RANK  ISD SCORE ISD RANK  \
# 0  Private not for Profit     100.0  ...      153       92.3      130
# 1                  Public      99.6  ...       35      100.0       22
# 2  Private not for Profit     100.0  ...      261       76.1      230
#
#    IRN SCORE IRN RANK  EO SCORE EO RANK  SUS SCORE SUS RANK  Overall SCORE
# 0       94.1       98     100.0       7       93.8       33            100
# ...

# %%
ds2.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
name2 = "datasets/Mobile Phone Pricing.csv"
d1 = pd.read_csv(name2)
d1
sns.scatterplot(data=d1,x=d1['clock_speed'],y=d1['battery_power'],hue=d1['price_range'],alpha=0.1)

sns.despine(right=False,top=False)

# %%
x = np.random.randint(0,500,1000)
y = np.random.randint(0,500,1000)
x+10
z = x-y
sns.stripplot(x=x, y=y, hue=z, dodge=True, jitter=True)
